# %% [markdown]
# # LSTM

# %%
#importing the needed libraries

import numpy as np
import matplotlib.pyplot as plt
from pandas import read_csv
import math
import pandas as pd

# %%
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.metrics import accuracy_score,r2_score,mean_absolute_error, mean_squared_error
import sklearn.metrics as metrics
from math import sqrt

# %%
#loading the dataset of active power

dataframe = read_csv('Daily_data.csv', usecols=[1])
plt.plot(dataframe)

# %%
#Converting pandas dataframe to numpy array

dataset = dataframe.values

#Converting values to float

dataset = dataset.astype('float32')

# %%
#normalizing the dataset

scaler = MinMaxScaler(feature_range=(0, 1)) 
dataset = scaler.fit_transform(dataset)

# %%
#spliting into train and test sets

train_size = int(len(dataset) * 0.66)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# %%
#seq_size is the number of previous time steps to use as input variables to predict the next time period.
#converting an array of values into a dataset matrix
#X is the active power at a given time (t, t-1, t-2...) 
#Y is the active power at the next time (t + 1).

def to_sequences(dataset, seq_size=1):
    x = []
    y = []

    for i in range(len(dataset)-seq_size-1):
        window = dataset[i:(i+seq_size), 0]
        x.append(window)
        y.append(dataset[i+seq_size, 0])
        
    return np.array(x),np.array(y)

# %%
seq_size = 5
trainX, trainY = to_sequences(train, seq_size)
testX, testY = to_sequences(test, seq_size)

# %%
print("Shape of training set: {}".format(trainX.shape))
print("Shape of test set: {}".format(testX.shape))
# Out:
# Shape of training set: (228, 5)
# Shape of test set: (116, 5)

# %%
# Reshaping input to be [samples, time steps, features]

trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %% [markdown]
# # model building

# %%
#model = Sequential()
#model.add(LSTM(64, input_shape=(None, seq_size)))
#model.add(Dense(32))
#model.add(Dense(1))
#model.compile(loss='mean_squared_error', optimizer='adam')
#monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience=20, verbose=1, mode='auto', restore_best_weights=True)
#model.summary()

# %%
#model = Sequential()
#model.add(LSTM(50, activation='relu', input_shape=(None, seq_size)))
#model.add(Dense(1))
#model.compile(optimizer='adam', loss='mse')

# %%
model = Sequential()
model.add(LSTM(50, activation='relu', return_sequences=True, input_shape=(None, seq_size)))
model.add(LSTM(50, activation='relu'))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %%
model.fit(trainX, trainY, validation_data=(testX, testY), verbose=2, epochs=150)
# Out:
# Epoch 1/150
# 8/8 - 5s - loss: 0.2030 - val_loss: 0.2471 - 5s/epoch - 572ms/step
# Epoch 2/150
# 8/8 - 0s - loss: 0.1892 - val_loss: 0.2319 - 120ms/epoch - 15ms/step
# Epoch 3/150
# 8/8 - 0s - loss: 0.1763 - val_loss: 0.2147 - 89ms/epoch - 11ms/step
# Epoch 4/150
# 8/8 - 0s - loss: 0.1612 - val_loss: 0.1930 - 116ms/epoch - 14ms/step
# Epoch 5/150
# 8/8 - 0s - loss: 0.1421 - val_loss: 0.1664 - 126ms/epoch - 16ms/step
# Epoch 6/150
# 8/8 - 0s - loss: 0.1197 - val_loss: 0.1332 - 122ms/epoch - 15ms/step
# Epoch 7/150
# 8/8 - 0s - loss: 0.0928 - val_loss: 0.0962 - 96ms/epoch - 12ms/step
# Epoch 8/150
# 8/8 - 0s - loss: 0.0641 - val_loss: 0.0614 - 78ms/epoch - 10ms/step
# Epoch 9/150
# 8/8 - 0s - loss: 0.0436 - val_loss: 0.0466 - 75ms/epoch - 9ms/step
# Epoch 10/150
# 8/8 - 0s - loss: 0.0425 - val_loss: 0.0499 - 97ms/epoch - 12ms/step
# Epoch 11/150
# 8/8 - 0s - loss: 0.0430 - val_loss: 0.0455 - 75ms/epoch - 9ms/step
# Epoch 12/150
# 8/8 - 0s - loss: 0.0406 - val_loss: 0.0457 - 72ms/epoch - 9ms/step
# Epoch 13/150
# 8/8 - 0s - loss: 0.0399 - val_loss: 0.0446 - 71ms/epoch - 9ms/step
# Epoch 14/150
# 8/8 - 0s - loss: 0.0394 - val_loss: 0.0440 - 66ms/epoch - 8ms/step
# Epoch 15/150
# 8/8 - 0s - loss: 0.0393 - val_loss: 0.0435 - 72ms/epoch - 9ms/step
# Epoch 16/150
# 8/8 - 0s - loss: 0.0386 - val_loss: 0.0435 - 68ms/epoch - 8ms/step
# Epoch 17/150
# 8/8 - 0s - loss: 0.0384 - val_loss: 0.0431 - 72ms/epoch - 9ms/step
# Epoch 18/150
# 8/8 - 0s - loss: 0.0383 - val_loss: 0.0429 - 70ms/epoch - 9ms/step
# Epoch 19/150
# 8/8 - 0s - loss: 0.0379 - val_loss: 0.0422 - 70ms/epoch - 9ms/step
# Epoch 20/150
# 8/8 - 0s - loss: 0.0376 - val_loss: 0.0414 - 66ms/epoch - 8ms/step
# Epoch 21/150
# 8/8 - 0s - loss: 0.0369 - val_loss: 0.0408 - 66ms/epoch - 8ms/step
# Epoch 22/150
# 8/8 - 0s - loss: 0.0367 - val_loss: 0.0404 - 70ms/epoch - 9ms/step
# Epoch 23/150
# 8/8 - 0s - loss: 0.0366 - val_loss: 0.0398 - 71ms/epoch - 9ms/step
# Epoch 24/150
# 8/8 - 0s - loss: 0.0362 - val_loss: 0.0397 - 68ms/epoch - 8ms/step
# Epoch 25/150
# 8/8 - 0s - loss: 0.0357 - val_loss: 0.0390 - 67ms/epoch - 8ms/step
# Epoch 26/150
# 8/8 - 0s - loss: 0.0353 - val_loss: 0.0384 - 69ms/epoch - 9ms/step
# Epoch 27/150
# 8/8 - 0s - loss: 0.0348 - val_loss: 0.0377 - 71ms/epoch - 9ms/step
# Epoch 28/150
# 8/8 - 0s - loss: 0.0347 - val_loss: 0.0372 - 72ms/epoch - 9ms/step
# Epoch 29/150
# 8/8 - 0s - loss: 0.0341 - val_loss: 0.0370 - 67ms/epoch - 8ms/step
# Epoch 30/150
# 8/8 - 0s - loss: 0.0338 - val_loss: 0.0365 - 69ms/epoch - 9ms/step
# Epoch 31/150
# 8/8 - 0s - loss: 0.0341 - val_loss: 0.0362 - 72ms/epoch - 9ms/step
# Epoch 32/150
# 8/8 - 0s - loss: 0.0337 - val_loss: 0.0366 - 65ms/epoch - 8ms/step
# Epoch 33/150
# 8/8 - 0s - loss: 0.0336 - val_loss: 0.0360 - 70ms/epoch - 9ms/step
# Epoch 34/150
# 8/8 - 0s - loss: 0.0331 - val_loss: 0.0349 - 72ms/epoch - 9ms/step
# Epoch 35/150
# 8/8 - 0s - loss: 0.0326 - val_loss: 0.0345 - 65ms/epoch - 8ms/step
# Epoch 36/150
# 8/8 - 0s - loss: 0.0324 - val_loss: 0.0342 - 70ms/epoch - 9ms/step
# Epoch 37/150
# 8/8 - 0s - loss: 0.0323 - val_loss: 0.0339 - 68ms/epoch - 8ms/step
# Epoch 38/150
# 8/8 - 0s - loss: 0.0319 - val_loss: 0.0340 - 89ms/epoch - 11ms/step
# Epoch 39/150
# 8/8 - 0s - loss: 0.0319 - val_loss: 0.0344 - 71ms/epoch - 9ms/step
# Epoch 40/150
# 8/8 - 0s - loss: 0.0319 - val_loss: 0.0331 - 77ms/epoch - 10ms/step
# Epoch 41/150
# 8/8 - 0s - loss: 0.0315 - val_loss: 0.0333 - 71ms/epoch - 9ms/step
# Epoch 42/150
# 8/8 - 0s - loss: 0.0322 - val_loss: 0.0331 - 83ms/epoch - 10ms/step
# Epoch 43/150
# 8/8 - 0s - loss: 0.0312 - val_loss: 0.0325 - 77ms/epoch - 10ms/step
# Epoch 44/150
# 8/8 - 0s - loss: 0.0309 - val_loss: 0.0324 - 79ms/epoch - 10ms/step
# Epoch 45/150
# 8/8 - 0s - loss: 0.0311 - val_loss: 0.0322 - 78ms/epoch - 10ms/step
# Epoch 46/150
# 8/8 - 0s - loss: 0.0307 - val_loss: 0.0321 - 78ms/epoch - 10ms/step
# Epoch 47/150
# 8/8 - 0s - loss: 0.0307 - val_loss: 0.0319 - 75ms/epoch - 9ms/step
# Epoch 48/150
# 8/8 - 0s - loss: 0.0306 - val_loss: 0.0317 - 75ms/epoch - 9ms/step
# Epoch 49/150
# 8/8 - 0s - loss: 0.0305 - val_loss: 0.0315 - 72ms/epoch - 9ms/step
# Epoch 50/150
# 8/8 - 0s - loss: 0.0304 - val_loss: 0.0313 - 85ms/epoch - 11ms/step
# Epoch 51/150
# 8/8 - 0s - loss: 0.0303 - val_loss: 0.0314 - 79ms/epoch - 10ms/step
# Epoch 52/150
# 8/8 - 0s - loss: 0.0303 - val_loss: 0.0311 - 82ms/epoch - 10ms/step
# Epoch 53/150
# 8/8 - 0s - loss: 0.0300 - val_loss: 0.0311 - 85ms/epoch - 11ms/step
# Epoch 54/150
# 8/8 - 0s - loss: 0.0299 - val_loss: 0.0308 - 83ms/epoch - 10ms/step
# Epoch 55/150
# 8/8 - 0s - loss: 0.0299 - val_loss: 0.0313 - 82ms/epoch - 10ms/step
# Epoch 56/150
# 8/8 - 0s - loss: 0.0297 - val_loss: 0.0302 - 81ms/epoch - 10ms/step
# Epoch 57/150
# 8/8 - 0s - loss: 0.0302 - val_loss: 0.0305 - 73ms/epoch - 9ms/step
# Epoch 58/150
# 8/8 - 0s - loss: 0.0299 - val_loss: 0.0298 - 76ms/epoch - 9ms/step
# Epoch 59/150
# 8/8 - 0s - loss: 0.0294 - val_loss: 0.0297 - 77ms/epoch - 10ms/step
# Epoch 60/150
# 8/8 - 0s - loss: 0.0295 - val_loss: 0.0302 - 78ms/epoch - 10ms/step
# Epoch 61/150
# 8/8 - 0s - loss: 0.0295 - val_loss: 0.0295 - 73ms/epoch - 9ms/step
# Epoch 62/150
# 8/8 - 0s - loss: 0.0293 - val_loss: 0.0294 - 78ms/epoch - 10ms/step
# Epoch 63/150
# 8/8 - 0s - loss: 0.0291 - val_loss: 0.0293 - 71ms/epoch - 9ms/step
# Epoch 64/150
# 8/8 - 0s - loss: 0.0290 - val_loss: 0.0292 - 74ms/epoch - 9ms/step
# Epoch 65/150
# 8/8 - 0s - loss: 0.0288 - val_loss: 0.0292 - 78ms/epoch - 10ms/step
# Epoch 66/150
# 8/8 - 0s - loss: 0.0291 - val_loss: 0.0301 - 80ms/epoch - 10ms/step
# Epoch 67/150
# 8/8 - 0s - loss: 0.0290 - val_loss: 0.0290 - 82ms/epoch - 10ms/step
# Epoch 68/150
# 8/8 - 0s - loss: 0.0294 - val_loss: 0.0290 - 74ms/epoch - 9ms/step
# Epoch 69/150
# 8/8 - 0s - loss: 0.0288 - val_loss: 0.0287 - 81ms/epoch - 10ms/step
# Epoch 70/150
# 8/8 - 0s - loss: 0.0285 - val_loss: 0.0297 - 69ms/epoch - 9ms/step
# Epoch 71/150
# 8/8 - 0s - loss: 0.0289 - val_loss: 0.0297 - 68ms/epoch - 8ms/step
# Epoch 72/150
# 8/8 - 0s - loss: 0.0293 - val_loss: 0.0297 - 65ms/epoch - 8ms/step
# Epoch 73/150
# 8/8 - 0s - loss: 0.0285 - val_loss: 0.0284 - 68ms/epoch - 8ms/step
# Epoch 74/150
# 8/8 - 0s - loss: 0.0283 - val_loss: 0.0283 - 64ms/epoch - 8ms/step
# Epoch 75/150
# 8/8 - 0s - loss: 0.0282 - val_loss: 0.0284 - 69ms/epoch - 9ms/step
# Epoch 76/150
# 8/8 - 0s - loss: 0.0281 - val_loss: 0.0292 - 70ms/epoch - 9ms/step
# Epoch 77/150
# 8/8 - 0s - loss: 0.0282 - val_loss: 0.0285 - 68ms/epoch - 8ms/step
# Epoch 78/150
# 8/8 - 0s - loss: 0.0279 - val_loss: 0.0283 - 68ms/epoch - 8ms/step
# Epoch 79/150
# 8/8 - 0s - loss: 0.0281 - val_loss: 0.0283 - 68ms/epoch - 8ms/step
# Epoch 80/150
# 8/8 - 0s - loss: 0.0283 - val_loss: 0.0284 - 64ms/epoch - 8ms/step
# Epoch 81/150
# 8/8 - 0s - loss: 0.0283 - val_loss: 0.0282 - 69ms/epoch - 9ms/step
# Epoch 82/150
# 8/8 - 0s - loss: 0.0280 - val_loss: 0.0284 - 70ms/epoch - 9ms/step
# Epoch 83/150
# 8/8 - 0s - loss: 0.0278 - val_loss: 0.0282 - 70ms/epoch - 9ms/step
# Epoch 84/150
# 8/8 - 0s - loss: 0.0276 - val_loss: 0.0280 - 64ms/epoch - 8ms/step
# Epoch 85/150
# 8/8 - 0s - loss: 0.0277 - val_loss: 0.0280 - 68ms/epoch - 8ms/step
# Epoch 86/150
# 8/8 - 0s - loss: 0.0276 - val_loss: 0.0279 - 65ms/epoch - 8ms/step
# Epoch 87/150
# 8/8 - 0s - loss: 0.0276 - val_loss: 0.0279 - 68ms/epoch - 8ms/step
# Epoch 88/150
# 8/8 - 0s - loss: 0.0274 - val_loss: 0.0279 - 69ms/epoch - 9ms/step
# Epoch 89/150
# 8/8 - 0s - loss: 0.0275 - val_loss: 0.0283 - 70ms/epoch - 9ms/step
# Epoch 90/150
# 8/8 - 0s - loss: 0.0280 - val_loss: 0.0283 - 68ms/epoch - 8ms/step
# Epoch 91/150
# 8/8 - 0s - loss: 0.0273 - val_loss: 0.0277 - 68ms/epoch - 8ms/step
# Epoch 92/150
# 8/8 - 0s - loss: 0.0275 - val_loss: 0.0276 - 70ms/epoch - 9ms/step
# Epoch 93/150
# 8/8 - 0s - loss: 0.0273 - val_loss: 0.0276 - 83ms/epoch - 10ms/step
# Epoch 94/150
# 8/8 - 0s - loss: 0.0272 - val_loss: 0.0278 - 69ms/epoch - 9ms/step
# Epoch 95/150
# 8/8 - 0s - loss: 0.0281 - val_loss: 0.0301 - 66ms/epoch - 8ms/step
# Epoch 96/150
# 8/8 - 0s - loss: 0.0279 - val_loss: 0.0276 - 66ms/epoch - 8ms/step
# Epoch 97/150
# 8/8 - 0s - loss: 0.0269 - val_loss: 0.0276 - 65ms/epoch - 8ms/step
# Epoch 98/150
# 8/8 - 0s - loss: 0.0278 - val_loss: 0.0276 - 67ms/epoch - 8ms/step
# Epoch 99/150
# 8/8 - 0s - loss: 0.0271 - val_loss: 0.0276 - 65ms/epoch - 8ms/step
# Epoch 100/150
# 8/8 - 0s - loss: 0.0270 - val_loss: 0.0275 - 73ms/epoch - 9ms/step
# Epoch 101/150
# 8/8 - 0s - loss: 0.0268 - val_loss: 0.0273 - 68ms/epoch - 8ms/step
# Epoch 102/150
# 8/8 - 0s - loss: 0.0269 - val_loss: 0.0273 - 68ms/epoch - 8ms/step
# Epoch 103/150
# 8/8 - 0s - loss: 0.0269 - val_loss: 0.0274 - 68ms/epoch - 8ms/step
# Epoch 104/150
# 8/8 - 0s - loss: 0.0269 - val_loss: 0.0272 - 68ms/epoch - 8ms/step
# Epoch 105/150
# 8/8 - 0s - loss: 0.0267 - val_loss: 0.0275 - 72ms/epoch - 9ms/step
# Epoch 106/150
# 8/8 - 0s - loss: 0.0267 - val_loss: 0.0272 - 67ms/epoch - 8ms/step
# Epoch 107/150
# 8/8 - 0s - loss: 0.0268 - val_loss: 0.0276 - 64ms/epoch - 8ms/step
# Epoch 108/150
# 8/8 - 0s - loss: 0.0272 - val_loss: 0.0272 - 67ms/epoch - 8ms/step
# Epoch 109/150
# 8/8 - 0s - loss: 0.0272 - val_loss: 0.0287 - 67ms/epoch - 8ms/step
# Epoch 110/150
# 8/8 - 0s - loss: 0.0268 - val_loss: 0.0274 - 66ms/epoch - 8ms/step
# Epoch 111/150
# 8/8 - 0s - loss: 0.0264 - val_loss: 0.0273 - 65ms/epoch - 8ms/step
# Epoch 112/150
# 8/8 - 0s - loss: 0.0266 - val_loss: 0.0273 - 79ms/epoch - 10ms/step
# Epoch 113/150
# 8/8 - 0s - loss: 0.0265 - val_loss: 0.0276 - 96ms/epoch - 12ms/step
# Epoch 114/150
# 8/8 - 0s - loss: 0.0263 - val_loss: 0.0272 - 72ms/epoch - 9ms/step
# Epoch 115/150
# 8/8 - 0s - loss: 0.0264 - val_loss: 0.0272 - 74ms/epoch - 9ms/step
# Epoch 116/150
# 8/8 - 0s - loss: 0.0265 - val_loss: 0.0271 - 77ms/epoch - 10ms/step
# Epoch 117/150
# 8/8 - 0s - loss: 0.0265 - val_loss: 0.0274 - 66ms/epoch - 8ms/step
# Epoch 118/150
# 8/8 - 0s - loss: 0.0262 - val_loss: 0.0273 - 67ms/epoch - 8ms/step
# Epoch 119/150
# 8/8 - 0s - loss: 0.0263 - val_loss: 0.0272 - 67ms/epoch - 8ms/step
# Epoch 120/150
# 8/8 - 0s - loss: 0.0262 - val_loss: 0.0271 - 68ms/epoch - 8ms/step
# Epoch 121/150
# 8/8 - 0s - loss: 0.0265 - val_loss: 0.0271 - 67ms/epoch - 8ms/step
# Epoch 122/150
# 8/8 - 0s - loss: 0.0262 - val_loss: 0.0280 - 67ms/epoch - 8ms/step
# Epoch 123/150
# 8/8 - 0s - loss: 0.0263 - val_loss: 0.0274 - 63ms/epoch - 8ms/step
# Epoch 124/150
# 8/8 - 0s - loss: 0.0261 - val_loss: 0.0273 - 67ms/epoch - 8ms/step
# Epoch 125/150
# 8/8 - 0s - loss: 0.0262 - val_loss: 0.0272 - 63ms/epoch - 8ms/step
# Epoch 126/150
# 8/8 - 0s - loss: 0.0260 - val_loss: 0.0273 - 66ms/epoch - 8ms/step
# Epoch 127/150
# 8/8 - 0s - loss: 0.0260 - val_loss: 0.0273 - 65ms/epoch - 8ms/step
# Epoch 128/150
# 8/8 - 0s - loss: 0.0260 - val_loss: 0.0272 - 68ms/epoch - 8ms/step
# Epoch 129/150
# 8/8 - 0s - loss: 0.0260 - val_loss: 0.0271 - 67ms/epoch - 8ms/step
# Epoch 130/150
# 8/8 - 0s - loss: 0.0259 - val_loss: 0.0277 - 67ms/epoch - 8ms/step
# Epoch 131/150
# 8/8 - 0s - loss: 0.0267 - val_loss: 0.0301 - 69ms/epoch - 9ms/step
# Epoch 132/150
# 8/8 - 0s - loss: 0.0274 - val_loss: 0.0283 - 83ms/epoch - 10ms/step
# Epoch 133/150
# 8/8 - 0s - loss: 0.0259 - val_loss: 0.0272 - 80ms/epoch - 10ms/step
# Epoch 134/150
# 8/8 - 0s - loss: 0.0267 - val_loss: 0.0273 - 78ms/epoch - 10ms/step
# Epoch 135/150
# 8/8 - 0s - loss: 0.0262 - val_loss: 0.0272 - 77ms/epoch - 10ms/step
# Epoch 136/150
# 8/8 - 0s - loss: 0.0262 - val_loss: 0.0304 - 81ms/epoch - 10ms/step
# Epoch 137/150
# 8/8 - 0s - loss: 0.0262 - val_loss: 0.0275 - 76ms/epoch - 9ms/step
# Epoch 138/150
# 8/8 - 0s - loss: 0.0262 - val_loss: 0.0276 - 81ms/epoch - 10ms/step
# Epoch 139/150
# 8/8 - 0s - loss: 0.0261 - val_loss: 0.0277 - 81ms/epoch - 10ms/step
# Epoch 140/150
# 8/8 - 0s - loss: 0.0256 - val_loss: 0.0275 - 78ms/epoch - 10ms/step
# Epoch 141/150
# 8/8 - 0s - loss: 0.0262 - val_loss: 0.0276 - 81ms/epoch - 10ms/step
# Epoch 142/150
# 8/8 - 0s - loss: 0.0254 - val_loss: 0.0281 - 79ms/epoch - 10ms/step
# Epoch 143/150
# 8/8 - 0s - loss: 0.0257 - val_loss: 0.0280 - 75ms/epoch - 9ms/step
# Epoch 144/150
# 8/8 - 0s - loss: 0.0257 - val_loss: 0.0276 - 80ms/epoch - 10ms/step
# Epoch 145/150
# 8/8 - 0s - loss: 0.0258 - val_loss: 0.0276 - 83ms/epoch - 10ms/step
# Epoch 146/150
# 8/8 - 0s - loss: 0.0259 - val_loss: 0.0275 - 75ms/epoch - 9ms/step
# Epoch 147/150
# 8/8 - 0s - loss: 0.0256 - val_loss: 0.0293 - 76ms/epoch - 9ms/step
# Epoch 148/150
# 8/8 - 0s - loss: 0.0267 - val_loss: 0.0296 - 76ms/epoch - 9ms/step
# Epoch 149/150
# 8/8 - 0s - loss: 0.0264 - val_loss: 0.0283 - 77ms/epoch - 10ms/step
# Epoch 150/150
# 8/8 - 0s - loss: 0.0256 - val_loss: 0.0277 - 76ms/epoch - 9ms/step

# %% [markdown]
# # making predictions

# %%
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# Out:
# 8/8 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 3ms/step

# %%
#inverting predictions back to prescaled values

trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])

# %% [markdown]
# # performance evaluation

# %%
#evaluating the performance

testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.7f RMSE' % (testScore))

testScore = metrics.mean_squared_error(testY[0], testPredict[:,0])
print('Test Score: %.7f MSE' % (testScore))

testScore = metrics.r2_score(testY[0], testPredict[:,0])
print('Test Score: %.7f R2-SCORE' % (testScore))

testScore = metrics.mean_absolute_error(testY[0], testPredict[:,0])
print('Test Score: %.7f MAE' % (testScore))
# Out:
# Test Score: 220.5746569 RMSE
# Test Score: 48653.1792670 MSE
# Test Score: 0.6386623 R2-SCORE
# Test Score: 168.1976043 MAE

# %%
#evaluating the performance

trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))

trainScore = metrics.mean_squared_error(trainY[0], trainPredict[:,0])
print('Train Score: %.2f MSE' % (trainScore))

trainScore = metrics.r2_score(trainY[0], trainPredict[:,0])
print('Train Score: %.2f R2-SCORE' % (trainScore))

trainScore = metrics.mean_absolute_error(trainY[0], trainPredict[:,0])
print('Train Score: %.2f MAE' % (trainScore))
# Out:
# Train Score: 211.56 RMSE
# Train Score: 44758.63 MSE
# Train Score: 0.64 R2-SCORE
# Train Score: 159.18 MAE

# %%
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[seq_size:len(trainPredict)+seq_size, :] = trainPredict

testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(seq_size*2)+1:len(dataset)-1, :] = testPredict

# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %%
#pd.DataFrame(trainPredictPlot).to_csv('C:/Users/jayan/OneDrive/Desktop/Dataset/Ptrain.csv')

# %%
#pd.DataFrame(testPredictPlot).to_csv('C:/Users/jayan/OneDrive/Desktop/Dataset/Ptest.csv')

# %%
#pd.DataFrame(testY).to_csv('C:/Users/jayan/OneDrive/Desktop/Dataset/test.csv')

# %%
#pd.DataFrame(trainY).to_csv('C:/Users/jayan/OneDrive/Desktop/Dataset/train.csv')
