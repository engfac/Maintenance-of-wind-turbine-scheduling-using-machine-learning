# %%
# Standard Math / Data libraries
import numpy as np
import pandas as pd

# Data Scrape Package
import pandas_datareader.data as web

# Plotting package
import matplotlib.pyplot as plt
# Scaling Package
from sklearn.preprocessing import MinMaxScaler

# Keras Network @ https://www.tensorflow.org/guide/keras/rnn
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# Set Random seed
import random
random.seed(2505)

# %%
# Load the data
df=pd.read_csv('D_data.csv',index_col='Date',parse_dates=True)
df.head(5)
# Out:
#             Wind speed  Generator speed  Blade angle  Wind direction  \
# Date
# 2020-01-01    5.313541        11.770079    -0.561819     -351.656781
# 2020-01-02    5.483615        12.008322    -0.100172     -348.796442
# 2020-01-03    5.140796        11.467794    -0.776094     -351.823328
# 2020-01-04    4.368247        10.245036    -0.776035     -361.517685
# 2020-01-05    5.700915        12.506949    -0.776141     -362.518394
#
#             Ambient temperature  Active power
# Date
# 2020-01-01            29.223170    259.196071
# 2020-01-02            29.447159    280.923954
# 2020-01-03            29.560999    231.064502
# 2020-01-04            29.573758    147.105333
# 2020-01-05            29.512227    296.006479

# %%
plt.plot(df['Active power'])

# %%
returns = df['Active power'].pct_change() # Used for univariate example.

column_names = df.columns
x = df.values #returns a numpy array
min_max_scaler = MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
df1 = pd.DataFrame(x_scaled)

# %%
pct_c_gold = df1

# %%
pct_c_gold.columns = column_names

# %%
pct_c_gold
# Out:
#      Wind speed  Generator speed  Blade angle  Wind direction  \
# 0      0.292347         0.640448     0.004892        0.194123
# 1      0.306730         0.655951     0.014094        0.197196
# 2      0.277738         0.620777     0.000621        0.193944
# 3      0.212401         0.541206     0.000622        0.183528
# 4      0.325108         0.688399     0.000620        0.182453
# ..          ...              ...          ...             ...
# 351    0.376202         0.780101     0.041377        0.632844
# 352    0.386909         0.622720     0.367285        0.652420
# 353    0.441597         0.883511     0.003941        0.638527
# 354    0.505052         0.926821     0.007340        0.636519
# 355    0.302878         0.663740     0.000205        0.620142
#
#      Ambient temperature  Active power
# 0               0.393000      0.183954
# 1               0.427688      0.200338
# 2               0.445319      0.162742
# 3               0.447295      0.099435
# 4               0.437765      0.211711
# ..                   ...           ...
# 351             0.255504      0.310295
# 352             0.210539      0.289813
# 353             0.149180      0.449356
# 354             0.206161      0.579414
# 355             0.362607      0.196530
#
# [356 rows x 6 columns]

# %%
returns
# Out:
# Date
# 2020-01-01         NaN
# 2020-01-02    0.083828
# 2020-01-03   -0.177484
# 2020-01-04   -0.363358
# 2020-01-05    1.012208
#                 ...
# 2020-12-17    0.166857
# 2020-12-18   -0.063652
# 2020-12-19    0.529516
# 2020-12-20    0.282218
# 2020-12-21   -0.647966
# Name: Active power, Length: 356, dtype: float64

# %%
plt.plot(returns)

# %%
# Flatten this matrix down.
npa = returns.values[1:].reshape(-1,1) # Python is smart to recognize whatever dimension you need by using this parameter
print(len(npa))
# # Let's scale the data -- this helps avoid the exploding gradient issue
scale = MinMaxScaler(feature_range=(0,1)) # This is by default.
npa = scale.fit_transform(npa)
print(len(npa))
# Out:
# 355
# 355

# %%
# Need the data to be in the form [sample, time steps, features (dimension of each element)]
samples = 10 # Number of samples (in past)
steps = 1 # Number of steps (in future)
X = [] # X array
Y = [] # Y array
for i in range(npa.shape[0] - samples):
    X.append(npa[i:i+samples]) # Independent Samples
    Y.append(npa[i+samples][0]) # Dependent Samples
print('Training Data: Length is ',len(X[0:1][0]),': ', X[0:1])
print('Testing Data: Length is ', len(Y[0:1]),': ', Y[0:1])
# Out:
# Training Data: Length is  10 :  [array([[0.14425651],
#        [0.10411174],
#        [0.07555626],
#        [0.28688149],
#        [0.25523229],
#        [0.20156907],
#        [0.09922402],
#        [0.03636268],
#        [0.15304486],
#        [0.3690607 ]])]
# Testing Data: Length is  1 :  [0.11233441507134656]

# %%
#Reshape the data so that the inputs will be acceptable to the model.
X = np.array(X)
Y = np.array(Y)
print('Dimensions of X', X.shape, 'Dimensions of Y', Y.shape)

threshold = round(0.9 * X.shape[0])
print('Threshold is', threshold)
# Out:
# Dimensions of X (345, 10, 1) Dimensions of Y (345,)
# Threshold is 310

# %%
# Let's build the RNN
model = keras.Sequential()

# Add a RNN layer with 3 units.
model.add(layers.SimpleRNN(3,
                           activation = 'tanh',
                           use_bias=True,
                           input_shape=(X.shape[1], X.shape[2])))
# Add a dropout layer (penalizing more complex models) -- prevents overfitting
model.add(layers.Dropout(rate=0.2))


# Add a Dense layer with 1 units (Since we are doing a regression task.
model.add(layers.Dense(1))

# Evaluating loss function of MSE using the adam optimizer.
model.compile(loss='mean_squared_error', optimizer = 'adam')

# Print out architecture.
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 3)                 15
#
#  dropout (Dropout)           (None, 3)                 0
#
#  dense (Dense)               (None, 1)                 4
#
# =================================================================
# Total params: 19
# Trainable params: 19
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fitting the data
history = model.fit(X[:threshold],
                    Y[:threshold],
                    shuffle = False, # Since this is time series data
                    epochs=100,
                    batch_size=32,
                    validation_split=0.2,
                    verbose=1) # Verbose outputs data
# Out:
# Epoch 1/100
# 8/8 [==============================] - 2s 47ms/step - loss: 1.1977 - val_loss: 0.9686
# Epoch 2/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.9918 - val_loss: 0.8259
# Epoch 3/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.8402 - val_loss: 0.6905
# Epoch 4/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.7473 - val_loss: 0.5614
# Epoch 5/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.6025 - val_loss: 0.4419
# Epoch 6/100
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4658 - val_loss: 0.3353
# Epoch 7/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.3547 - val_loss: 0.2462
# Epoch 8/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.2604 - val_loss: 0.1761
# Epoch 9/100
# 8/8 [==============================] - 0s 8ms/step - loss: 0.1942 - val_loss: 0.1241
# Epoch 10/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.1532 - val_loss: 0.0882
# Epoch 11/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.1080 - val_loss: 0.0664
# Epoch 12/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0729 - val_loss: 0.0541
# Epoch 13/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0724 - val_loss: 0.0478
# Epoch 14/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0611 - val_loss: 0.0447
# Epoch 15/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0704 - val_loss: 0.0429
# Epoch 16/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0600 - val_loss: 0.0417
# Epoch 17/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0680 - val_loss: 0.0408
# Epoch 18/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0613 - val_loss: 0.0400
# Epoch 19/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0585 - val_loss: 0.0393
# Epoch 20/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0567 - val_loss: 0.0386
# Epoch 21/100
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0575 - val_loss: 0.0380
# Epoch 22/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0428 - val_loss: 0.0374
# Epoch 23/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0538 - val_loss: 0.0369
# Epoch 24/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0574 - val_loss: 0.0363
# Epoch 25/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0579 - val_loss: 0.0358
# Epoch 26/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0546 - val_loss: 0.0352
# Epoch 27/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0522 - val_loss: 0.0347
# Epoch 28/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0481 - val_loss: 0.0342
# Epoch 29/100
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0505 - val_loss: 0.0338
# Epoch 30/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0435 - val_loss: 0.0333
# Epoch 31/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0523 - val_loss: 0.0329
# Epoch 32/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0475 - val_loss: 0.0325
# Epoch 33/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0456 - val_loss: 0.0321
# Epoch 34/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0496 - val_loss: 0.0317
# Epoch 35/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0483 - val_loss: 0.0313
# Epoch 36/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0443 - val_loss: 0.0309
# Epoch 37/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0433 - val_loss: 0.0306
# Epoch 38/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0377 - val_loss: 0.0302
# Epoch 39/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0420 - val_loss: 0.0299
# Epoch 40/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0467 - val_loss: 0.0296
# Epoch 41/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0421 - val_loss: 0.0293
# Epoch 42/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0414 - val_loss: 0.0290
# Epoch 43/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0364 - val_loss: 0.0287
# Epoch 44/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0393 - val_loss: 0.0284
# Epoch 45/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0408 - val_loss: 0.0281
# Epoch 46/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0419 - val_loss: 0.0278
# Epoch 47/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0385 - val_loss: 0.0276
# Epoch 48/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0404 - val_loss: 0.0273
# Epoch 49/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0404 - val_loss: 0.0270
# Epoch 50/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0400 - val_loss: 0.0267
# Epoch 51/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0352 - val_loss: 0.0265
# Epoch 52/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0409 - val_loss: 0.0262
# Epoch 53/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0302 - val_loss: 0.0260
# Epoch 54/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0313 - val_loss: 0.0258
# Epoch 55/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0435 - val_loss: 0.0256
# Epoch 56/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0380 - val_loss: 0.0253
# Epoch 57/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0335 - val_loss: 0.0251
# Epoch 58/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0416 - val_loss: 0.0249
# Epoch 59/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0370 - val_loss: 0.0247
# Epoch 60/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0350 - val_loss: 0.0245
# Epoch 61/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0354 - val_loss: 0.0243
# Epoch 62/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0365 - val_loss: 0.0241
# Epoch 63/100
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0327 - val_loss: 0.0239
# Epoch 64/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0381 - val_loss: 0.0237
# Epoch 65/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0333 - val_loss: 0.0235
# Epoch 66/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0344 - val_loss: 0.0233
# Epoch 67/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0319 - val_loss: 0.0231
# Epoch 68/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0313 - val_loss: 0.0230
# Epoch 69/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0290 - val_loss: 0.0228
# Epoch 70/100
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0371 - val_loss: 0.0226
# Epoch 71/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0285 - val_loss: 0.0225
# Epoch 72/100
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0302 - val_loss: 0.0223
# Epoch 73/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0364 - val_loss: 0.0221
# Epoch 74/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0328 - val_loss: 0.0220
# Epoch 75/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0302 - val_loss: 0.0218
# Epoch 76/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0297 - val_loss: 0.0217
# Epoch 77/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0313 - val_loss: 0.0215
# Epoch 78/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0305 - val_loss: 0.0214
# Epoch 79/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0299 - val_loss: 0.0212
# Epoch 80/100
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0310 - val_loss: 0.0211
# Epoch 81/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0292 - val_loss: 0.0209
# Epoch 82/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0311 - val_loss: 0.0208
# Epoch 83/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0269 - val_loss: 0.0207
# Epoch 84/100
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0262 - val_loss: 0.0205
# Epoch 85/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0313 - val_loss: 0.0204
# Epoch 86/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0313 - val_loss: 0.0203
# Epoch 87/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0309 - val_loss: 0.0202
# Epoch 88/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0316 - val_loss: 0.0200
# Epoch 89/100
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0285 - val_loss: 0.0199
# Epoch 90/100
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0265 - val_loss: 0.0198
# Epoch 91/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0265 - val_loss: 0.0196
# Epoch 92/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0299 - val_loss: 0.0195
# Epoch 93/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0249 - val_loss: 0.0194
# Epoch 94/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0255 - val_loss: 0.0193
# Epoch 95/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0273 - val_loss: 0.0192
# Epoch 96/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0288 - val_loss: 0.0191
# Epoch 97/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0270 - val_loss: 0.0189
# Epoch 98/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0250 - val_loss: 0.0188
# Epoch 99/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0275 - val_loss: 0.0187
# Epoch 100/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0259 - val_loss: 0.0186

# %%
# Plotting the loss iteration
plt.plot(history.history['loss'], label = 'training loss')
plt.plot(history.history['val_loss'], label ='validation loss')
plt.legend()
# Note:
# if training loss >> validation loss -> Underfitting
# if training loss << validation loss -> Overfitting (i.e model is smart enough to have mapped the entire dataset..)
# Several ways to address overfitting:
# Reduce complexity of model (hidden layers, neurons, parameters input etc)
# Add dropout and tune rate
# More data :)

# %%
# Predictions using the 'sliding/rolling window approach'
# Multi step forecast.
# Using self predictions for making future predictions

true_Y = Y[threshold:]
pred_Y = []
print('Number of Forecasts to do: ',Y.shape[0] - round(Y.shape[0]*0.9))
latest_input = X[threshold-1:threshold]
for i in range(Y.shape[0] - round(Y.shape[0]*0.9) ):
    # Prediction
    p = model.predict(latest_input.reshape(1,X.shape[1],1))[0,0]
    
    # Update predictions
    pred_Y.append(p)
    latest_input = np.append(X[threshold][1:], p)
# Out:
# Number of Forecasts to do:  35
# 1/1 [==============================] - 0s 251ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step

# %%
plt.plot(true_Y, label = 'True Value')
plt.plot(pred_Y, label = 'Forecasted Value')
plt.legend()
# Model just copied the same value over and over again. Hence, model is not very robust.
# It's just predicting the mean.

# %% [markdown]
# ### Multi-Variate Forecasting

# %%
# Need the data to be in the form [sample, time steps, features (dimension of each element)]
samples = 10 # Number of samples (in past)
steps = 1 # Number of steps (in future)
X = [] # X array
Y = [] # Y array
for i in range(pct_c_gold.shape[0] - samples):
    X.append(pct_c_gold.iloc[i:i+samples, 0:5].values) # Independent Samples
    Y.append(pct_c_gold.iloc[i+samples, 5:].values) # Dependent Samples
print('Training Data: Length is ',len(X[0:1][0]),': ', X[0:1])
print('Testing Data: Length is ', len(Y[0:1]),': ', Y[0:1])
# Out:
# Training Data: Length is  10 :  [array([[2.92346970e-01, 6.40447526e-01, 4.89213032e-03, 1.94122926e-01,
#         3.92999632e-01],
#        [3.06730487e-01, 6.55951060e-01, 1.40940090e-02, 1.97196159e-01,
#         4.27688404e-01],
#        [2.77737514e-01, 6.20776516e-01, 6.21043161e-04, 1.93943983e-01,
#         4.45318651e-01],
#        [2.12401237e-01, 5.41206199e-01, 6.22205898e-04, 1.83528076e-01,
#         4.47294511e-01],
#        [3.25108050e-01, 6.88398940e-01, 6.20101898e-04, 1.82452884e-01,
#         4.37765380e-01],
#        [4.25407753e-01, 8.37130916e-01, 1.93408450e-03, 2.03088273e-01,
#         4.52055849e-01],
#        [5.13188581e-01, 9.31330782e-01, 7.46964081e-03, 2.08047565e-01,
#         4.50783778e-01],
#        [4.56222319e-01, 8.86329635e-01, 3.69683053e-03, 2.22685790e-01,
#         3.54693612e-01],
#        [2.81132623e-01, 6.24199251e-01, 4.06079678e-03, 2.17329848e-01,
#         2.74620586e-01],
#        [3.08336715e-01, 6.62348284e-01, 4.06022924e-03, 2.09889124e-01,
#         3.23597032e-01]])]
# Testing Data: Length is  1 :  [array([0.5034589])]

# %%
#Reshape the data so that the inputs will be acceptable to the model.
X = np.array(X)
Y = np.array(Y)
print('Dimensions of X', X.shape, 'Dimensions of Y', Y.shape)
# Out:
# Dimensions of X (346, 10, 5) Dimensions of Y (346, 1)

# %%
# # Get the training and testing set
threshold = round(0.9 * X.shape[0])
trainX, trainY = X[:threshold], Y[:threshold]
testX, testY =  X[threshold:], Y[threshold:]
print('Training Length',trainX.shape, trainY.shape,'Testing Length:',testX.shape, testY.shape)
# Out:
# Training Length (311, 10, 5) (311, 1) Testing Length: (35, 10, 5) (35, 1)

# %%
# Let's build the RNN
model = keras.Sequential()

# Add a RNN layer with 30 internal units.
model.add(layers.SimpleRNN(30,
                           activation = 'tanh',
                           use_bias=True,
                           input_shape=(trainX.shape[1], trainX.shape[2])))
# Add a dropout layer (penalizing more complex models) -- prevents overfitting
model.add(layers.Dropout(rate=0.2))


# Add a Dense layer with 1 units (Since we are doing a regression task.
model.add(layers.Dense(1))

# Evaluating loss function of MSE using the adam optimizer.
model.compile(loss='mean_squared_error', optimizer = 'adam')

# Print out architecture.
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_1 (SimpleRNN)    (None, 30)                1080
#
#  dropout_1 (Dropout)         (None, 30)                0
#
#  dense_1 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 1,111
# Trainable params: 1,111
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fitting the data
history = model.fit(trainX,
                    trainY,
                    shuffle = False, # Since this is time series data
                    epochs=100,
                    batch_size=32,
                    validation_split=0.2,
                    verbose=1) # Verbose outputs data
# Out:
# Epoch 1/100
# 8/8 [==============================] - 2s 39ms/step - loss: 0.5605 - val_loss: 0.1197
# Epoch 2/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.2202 - val_loss: 0.2180
# Epoch 3/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.2670 - val_loss: 0.1461
# Epoch 4/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.1972 - val_loss: 0.1033
# Epoch 5/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.1976 - val_loss: 0.0937
# Epoch 6/100
# 8/8 [==============================] - 0s 8ms/step - loss: 0.1574 - val_loss: 0.0920
# Epoch 7/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.1232 - val_loss: 0.0940
# Epoch 8/100
# 8/8 [==============================] - 0s 8ms/step - loss: 0.1581 - val_loss: 0.0857
# Epoch 9/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.1339 - val_loss: 0.0759
# Epoch 10/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.1049 - val_loss: 0.0714
# Epoch 11/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0936 - val_loss: 0.0715
# Epoch 12/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.1004 - val_loss: 0.0688
# Epoch 13/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0944 - val_loss: 0.0656
# Epoch 14/100
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0862 - val_loss: 0.0668
# Epoch 15/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0880 - val_loss: 0.0568
# Epoch 16/100
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0794 - val_loss: 0.0522
# Epoch 17/100
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0811 - val_loss: 0.0559
# Epoch 18/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0693 - val_loss: 0.0599
# Epoch 19/100
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0651 - val_loss: 0.0568
# Epoch 20/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0673 - val_loss: 0.0512
# Epoch 21/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0647 - val_loss: 0.0505
# Epoch 22/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0573 - val_loss: 0.0517
# Epoch 23/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0584 - val_loss: 0.0473
# Epoch 24/100
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0594 - val_loss: 0.0480
# Epoch 25/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0570 - val_loss: 0.0501
# Epoch 26/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0556 - val_loss: 0.0500
# Epoch 27/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0501 - val_loss: 0.0420
# Epoch 28/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0491 - val_loss: 0.0430
# Epoch 29/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0521 - val_loss: 0.0447
# Epoch 30/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0470 - val_loss: 0.0420
# Epoch 31/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0455 - val_loss: 0.0409
# Epoch 32/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0509 - val_loss: 0.0425
# Epoch 33/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0501 - val_loss: 0.0448
# Epoch 34/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0386 - val_loss: 0.0357
# Epoch 35/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0476 - val_loss: 0.0371
# Epoch 36/100
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0449 - val_loss: 0.0376
# Epoch 37/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0418 - val_loss: 0.0363
# Epoch 38/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0405 - val_loss: 0.0338
# Epoch 39/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0398 - val_loss: 0.0356
# Epoch 40/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0448 - val_loss: 0.0363
# Epoch 41/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0399 - val_loss: 0.0385
# Epoch 42/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0475 - val_loss: 0.0367
# Epoch 43/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0395 - val_loss: 0.0355
# Epoch 44/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0370 - val_loss: 0.0328
# Epoch 45/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0375 - val_loss: 0.0334
# Epoch 46/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0401 - val_loss: 0.0329
# Epoch 47/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0392 - val_loss: 0.0304
# Epoch 48/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0342 - val_loss: 0.0295
# Epoch 49/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0412 - val_loss: 0.0327
# Epoch 50/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0354 - val_loss: 0.0328
# Epoch 51/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0339 - val_loss: 0.0298
# Epoch 52/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0331 - val_loss: 0.0288
# Epoch 53/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0370 - val_loss: 0.0312
# Epoch 54/100
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0297 - val_loss: 0.0303
# Epoch 55/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0381 - val_loss: 0.0285
# Epoch 56/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0332 - val_loss: 0.0306
# Epoch 57/100
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0382 - val_loss: 0.0302
# Epoch 58/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0359 - val_loss: 0.0288
# Epoch 59/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0325 - val_loss: 0.0304
# Epoch 60/100
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0344 - val_loss: 0.0314
# Epoch 61/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0307 - val_loss: 0.0309
# Epoch 62/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0342 - val_loss: 0.0293
# Epoch 63/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0344 - val_loss: 0.0290
# Epoch 64/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0338 - val_loss: 0.0288
# Epoch 65/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0324 - val_loss: 0.0278
# Epoch 66/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0306 - val_loss: 0.0299
# Epoch 67/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0328 - val_loss: 0.0281
# Epoch 68/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0345 - val_loss: 0.0267
# Epoch 69/100
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0313 - val_loss: 0.0297
# Epoch 70/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0308 - val_loss: 0.0287
# Epoch 71/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0291 - val_loss: 0.0284
# Epoch 72/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0314 - val_loss: 0.0276
# Epoch 73/100
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0328 - val_loss: 0.0273
# Epoch 74/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0300 - val_loss: 0.0303
# Epoch 75/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0336 - val_loss: 0.0255
# Epoch 76/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0293 - val_loss: 0.0299
# Epoch 77/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0331 - val_loss: 0.0272
# Epoch 78/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0326 - val_loss: 0.0276
# Epoch 79/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0317 - val_loss: 0.0299
# Epoch 80/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0272 - val_loss: 0.0307
# Epoch 81/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0348 - val_loss: 0.0279
# Epoch 82/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0330 - val_loss: 0.0291
# Epoch 83/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0314 - val_loss: 0.0308
# Epoch 84/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0324 - val_loss: 0.0269
# Epoch 85/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0286 - val_loss: 0.0286
# Epoch 86/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0290 - val_loss: 0.0325
# Epoch 87/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0307 - val_loss: 0.0263
# Epoch 88/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0287 - val_loss: 0.0295
# Epoch 89/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0292 - val_loss: 0.0273
# Epoch 90/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0285 - val_loss: 0.0271
# Epoch 91/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0248 - val_loss: 0.0278
# Epoch 92/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0304 - val_loss: 0.0268
# Epoch 93/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0274 - val_loss: 0.0265
# Epoch 94/100
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0300 - val_loss: 0.0263
# Epoch 95/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0328 - val_loss: 0.0276
# Epoch 96/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0302 - val_loss: 0.0268
# Epoch 97/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0261 - val_loss: 0.0268
# Epoch 98/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0290 - val_loss: 0.0286
# Epoch 99/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0302 - val_loss: 0.0283
# Epoch 100/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0240 - val_loss: 0.0254

# %%
# Plotting the loss iteration
plt.plot(history.history['loss'], label = 'training loss')
plt.plot(history.history['val_loss'], label ='validation loss')
plt.legend()
# Note:
# if training loss >> validation loss -> Underfitting
# if training loss << validation loss -> Overfitting (i.e model is smart enough to have mapped the entire dataset..)
# Several ways to address overfitting:
# Reduce complexity of model (hidden layers, neurons, parameters input etc)
# Add dropout and tune rate
# More data :)

# %%
# This is a one step forecast (based on how we constructed our model)
y_pred = model.predict(testX)
plt.plot(testY, label = 'True Value')
plt.plot(y_pred, label = 'Forecasted Value')
plt.legend()
# Out:
# 2/2 [==============================] - 0s 4ms/step

# %%
# Predictions using the 'sliding/rolling window approach'
# Multi step forecast.
# Using self predictions for making future predictions
# Very much different from a univariate -- You will need predictions (or known) values for your independent values.
# Nonetheles, you will follow the same steps as shown for the univariate multi-step process.

# %%
len(X[threshold:])
# Out:
# 35
